# %% [markdown]
# # Modelos de Lotsizing Simples (sem setup)

# %% [markdown]
# *   Empresas fabricam diversos tipos de produtos
# *   Produtos demandados por clientes em datas específicas
# *   Fábricas com capacidade limitda de produção
# *   Antecipação na produção acarreta custos de estocagem

# %% [markdown]
# Fabricar dois tipos de vigas com demandas conhecidas para três semanas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Suponha a disponibilidade de 40 horas de trabalho por período
#
# *   produzir 1 unidade do item 1 consome 15 minutos
# *   produzir 1 unidade do item 2 consome 20 minutos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Admite-se estocar a produção para ser utilizada nos períodos seguintes com os seguintes custos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Objetivo**: determinar o tamanho dos lotes para produção, atendendo a demanda na data com custos de produção e estocagem mínimos

# %% [markdown]
# Considere que a produção de vigas é contínua, isto é, podem ser produzidas quantidades fracionárias de vigas

# %% [markdown]
# Considere a aplicação de horas extras. Cada hora extra implica em um custo de X, que deve ser lido para cada caso de teste

# %% [markdown]
# Não se esqueça de usar o comando
#
# > model.setParam("display/verblevel", 0)
#
# Para desabilitar a impressão do log do Scip

# %% [markdown]
# ## Entrada

# %% [markdown]
# Um int X indicando o custo por hora extra realizada

# %% [markdown]
# ## Saída

# %% [markdown]
# Um int (utilize math.floor para arredondamento) indicando o custo do plano de produção gerado

# %% [markdown]
# **Dica: modifique os códigos do Dr. Caio Tomazella para rodar no Scip**
